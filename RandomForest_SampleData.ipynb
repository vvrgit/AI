# %% [markdown]
# <a href="https://colab.research.google.com/github/vvrgit/AI/blob/main/RandomForest_SampleData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
data=pd.read_excel("/content/DT-Data.xlsx")
data.head()
# Out:
#    Outlook  Temp  Humidity  Wind  Play
# 0        2     1         0     1     0
# 1        2     1         0     0     0
# 2        0     1         0     1     1
# 3        1     2         0     1     1
# 4        1     0         1     1     1

# %%
y=data.pop("Play")
x=data

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=0)

# %%
classifier = RandomForestClassifier(n_estimators=2, random_state=42)

# %%
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=2, random_state=42)

# %%
y_pred = classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 33.33%

# %%
import numpy as np
ip=np.array([2,1,0,1])
y_pred = classifier.predict([ip])
print(y_pred)
# Out:
# [0]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
